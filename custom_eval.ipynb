# %% [markdown]
# ### Setup Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NhuGiap04/DAS.git
# Out:
# Cloning into 'DAS'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 228 (delta 119), reused 167 (delta 61), pack-reused 0 (from 0)
# Receiving objects: 100% (228/228), 12.87 MiB | 25.95 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# %cd DAS
# Out:
# /content/DAS

# %%
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 9.93 KiB | 4.97 MiB/s, done.
# From https://github.com/NhuGiap04/DAS
#    2ddcdd4..9b0999d  main       -> origin/main
# Updating 2ddcdd4..9b0999d
# Fast-forward
#  custom_eval.ipynb   | 824 +++++++++++++++++++++++++++++++++++++++++++++++++---
#  runs/baseline/sd.py |   4 +-
#  2 files changed, 782 insertions(+), 46 deletions(-)

# %%
# %pip install -e .
# %pip install --no-deps image-reward
# Out:
# Obtaining file:///content/DAS
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached numpy-2.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached scipy-1.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached ml_collections-0.1.1.tar.gz (77 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached diffusers-0.32.2-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# ...
#   Using cached torchvision-0.18.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached timm-1.0.14-py3-none-any.whl.metadata (50 kB)
# ...

# %% [markdown]
# ### Run Evaluation

# %%
# !python runs/baseline/run_sd_batch.py \
    --seed 42 \
    --n_steps 100 \
    --num_images 4 \
    --prompts_file assets/hps_v2_all_eval.txt \
    --save-final-artifacts \
    --output_dir /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/
# Out:
# ...
# Baseline SD Batch Runner
# ...
# Prompt file : assets/hps_v2_all_eval.txt
# Script      : runs/baseline/sd.py
# Runs        : 50 (from index 0)
# Output root : /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2
# Log dir     : /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/_batch_logs
# Artifacts   : /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/_batch_artifacts
#
# [001/050] A passenger jet being serviced on a runway in an airport.
#   output: /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/run_0000_a-passenger-jet-being-serviced-on-a-runw
#   status: OK  time: 85.68s
#   final rewards: /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/_batch_artifacts/run_0000_a-passenger-jet-being-serviced-on-a-runw/final_rewards.json
#   final images: 4 files
#
# [002/050] Three people are preparing a meal in a small kitchen.
#   output: /content/drive/MyDrive/Logs/DAS/HPS_all/baseline_v2/run_0001_three-people-are-preparing-a-meal-in-a-s
#   status: OK  time: 39.84s
# ...

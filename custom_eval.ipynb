# %% [markdown]
# ### Setup Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NhuGiap04/DAS.git
# Out:
# Cloning into 'DAS'...
# remote: Enumerating objects: 242, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 242 (delta 130), reused 179 (delta 70), pack-reused 0 (from 0)
# Receiving objects: 100% (242/242), 12.88 MiB | 10.61 MiB/s, done.
# Resolving deltas: 100% (130/130), done.

# %%
# %cd DAS
# Out:
# /content/DAS

# %%
# !git pull
# Out:
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 12 (delta 7), reused 12 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 19.33 KiB | 3.87 MiB/s, done.
# From https://github.com/NhuGiap04/DAS
#    11bb18d..a5b3835  main       -> origin/main
# Updating 11bb18d..a5b3835
# Fast-forward
#  custom_eval.ipynb   | 1789 ++++++++++++++++++++++++++++++++++++++++++++++-----
#  runs/single/lcm.py  |   13 +
#  runs/single/sd.py   |   13 +
#  runs/single/sdxl.py |   13 +
#  4 files changed, 1661 insertions(+), 167 deletions(-)

# %%
# %pip install -e .
# %pip install --no-deps image-reward
# Out:
# Obtaining file:///content/DAS
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 30.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 14.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Run Evaluation

# %%
# !python runs/single/sd.py \
    --seed 42 \
    --prompt "A passenger jet being serviced on a runway in an airport." \
    --n_steps 100 \
    --batch_p 1 \
    --num_particles 4 \
    --kl_coeff 0.001 \
    --save-final-artifacts \
    --output_dir /content/DAS/logs/kl_0.001/
# Out:
# 2026-04-28 03:01:42.627052: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-28 03:01:42.644726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777345302.666016   37394 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777345302.672694   37394 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !zip -r logs_das.zip /content/DAS/logs -x "*/.ipynb_checkpoints/*"
# Out:
#   adding: content/DAS/logs/ (stored 0%)
#   adding: content/DAS/logs/kl_0.5/ (stored 0%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/ (stored 0%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/final_rewards.json (deflated 69%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/final_particles/ (stored 0%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/final_particles/final_particle_002.png (deflated 0%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/final_particles/final_particle_000.png (deflated 0%)
#   adding: content/DAS/logs/kl_0.5/a-passenger-jet-being-serviced-on-a-runway-in-an-airport/final_particles/final_particle_001.png (deflated 0%)
# ...

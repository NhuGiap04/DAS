# %% [markdown]
# ### Setup Environment

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/NhuGiap04/DAS.git

# %%
# %cd DAS

# %%
# !git pull

# %%
# %pip install -e .
# %pip install --no-deps image-reward

# %% [markdown]
# ### Run Evaluation

# %%
# !python runs/run_sd_batch.py \
    --n_steps 100 \
    --num_particles 4 \
    --batch_p 2 \
    --kl_coeff 1.0 \
    --prompts_file assets/hps_v2_all_eval.txt \
    --start_index 0 \
    --save-final-artifacts \
    --output_dir /content/drive/MyDrive/Logs/DAS/HPS_all/
